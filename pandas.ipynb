# %% [markdown]
# <a href="https://colab.research.google.com/github/Vamshi0505/data-science/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df
# Out:
#            Song_Title                         Artist       Genre  \
# 0               Faded                    Alan Walker  Electronic
# 1     Blinding Lights                     The Weeknd   Synth-pop
# 2               Faded                    Alan Walker  Electronic
# 3               Faded                    Alan Walker  Electronic
# 4   Bohemian Rhapsody                          Queen        Rock
# ..                ...                            ...         ...
# 95     Counting Stars                    OneRepublic    Pop Rock
# 96           Senorita  Shawn Mendes & Camila Cabello   Latin Pop
# 97     Counting Stars                    OneRepublic    Pop Rock
# 98    Blinding Lights                     The Weeknd   Synth-pop
# 99         Let Her Go                      Passenger       Indie
#
#     Release_Year  Duration_Minutes Listened_Date     Platform
# 0           2024              4.02    2024-02-10  Apple Music
# ...

# %%
df.head()
# Out:
#           Song_Title       Artist       Genre  Release_Year  Duration_Minutes  \
# 0              Faded  Alan Walker  Electronic          2024              4.02
# 1    Blinding Lights   The Weeknd   Synth-pop          2018              4.45
# 2              Faded  Alan Walker  Electronic          2024              4.86
# 3              Faded  Alan Walker  Electronic          2012              4.92
# 4  Bohemian Rhapsody        Queen        Rock          2023              3.90
#
#   Listened_Date     Platform
# 0    2024-02-10  Apple Music
# 1    2024-05-30     Zing MP3
# 2    2024-05-07     Zing MP3
# 3    2024-03-19      YouTube
# 4    2024-01-16  Apple Music

# %%
df.tail()
# Out:
#          Song_Title                         Artist      Genre  Release_Year  \
# 95   Counting Stars                    OneRepublic   Pop Rock          2013
# 96         Senorita  Shawn Mendes & Camila Cabello  Latin Pop          2024
# 97   Counting Stars                    OneRepublic   Pop Rock          2010
# 98  Blinding Lights                     The Weeknd  Synth-pop          2012
# 99       Let Her Go                      Passenger      Indie          2013
#
#     Duration_Minutes Listened_Date     Platform
# 95              3.40    2024-05-30      Spotify
# 96              2.75    2024-06-11  Apple Music
# 97              3.57    2024-01-03     Zing MP3
# 98              4.04    2024-06-13  Apple Music
# 99              4.61    2024-01-04  Apple Music

# %%
df.iloc[3:]
# Out:
#            Song_Title                         Artist       Genre  \
# 3               Faded                    Alan Walker  Electronic
# 4   Bohemian Rhapsody                          Queen        Rock
# 5             Perfect                     Ed Sheeran  Pop Ballad
# 6          Let Her Go                      Passenger       Indie
# 7     Blinding Lights                     The Weeknd   Synth-pop
# ..                ...                            ...         ...
# 95     Counting Stars                    OneRepublic    Pop Rock
# 96           Senorita  Shawn Mendes & Camila Cabello   Latin Pop
# 97     Counting Stars                    OneRepublic    Pop Rock
# 98    Blinding Lights                     The Weeknd   Synth-pop
# 99         Let Her Go                      Passenger       Indie
#
#     Release_Year  Duration_Minutes Listened_Date     Platform
# 3           2012              4.92    2024-03-19      YouTube
# ...

# %%
df.loc[1:10,["Song_Title","Artist"]]
# Out:
#            Song_Title          Artist
# 1     Blinding Lights      The Weeknd
# 2               Faded     Alan Walker
# 3               Faded     Alan Walker
# 4   Bohemian Rhapsody           Queen
# 5             Perfect      Ed Sheeran
# 6          Let Her Go       Passenger
# 7     Blinding Lights      The Weeknd
# 8          Let Her Go       Passenger
# 9   Bohemian Rhapsody           Queen
# 10             Havana  Camila Cabello

# %%
df["Song_Title"]
# Out:
# 0                 Faded
# 1       Blinding Lights
# 2                 Faded
# 3                 Faded
# 4     Bohemian Rhapsody
#             ...
# 95       Counting Stars
# 96             Senorita
# 97       Counting Stars
# 98      Blinding Lights
# 99           Let Her Go
# Name: Song_Title, Length: 100, dtype: object

# %%
df.drop("Genre",axis=1)
# Out:
#            Song_Title                         Artist  Release_Year  \
# 0               Faded                    Alan Walker          2024
# 1     Blinding Lights                     The Weeknd          2018
# 2               Faded                    Alan Walker          2024
# 3               Faded                    Alan Walker          2012
# 4   Bohemian Rhapsody                          Queen          2023
# ..                ...                            ...           ...
# 95     Counting Stars                    OneRepublic          2013
# 96           Senorita  Shawn Mendes & Camila Cabello          2024
# 97     Counting Stars                    OneRepublic          2010
# 98    Blinding Lights                     The Weeknd          2012
# 99         Let Her Go                      Passenger          2013
#
#     Duration_Minutes Listened_Date     Platform
# 0               4.02    2024-02-10  Apple Music
# 1               4.45    2024-05-30     Zing MP3
# ...

# %%
df.shape
# Out:
# (100, 7)

# %%
#Brodcasting
df['Duration_Minutes']=df['Duration_Minutes']-1.00
df
# Out:
#            Song_Title                         Artist       Genre  \
# 0               Faded                    Alan Walker  Electronic
# 1     Blinding Lights                     The Weeknd   Synth-pop
# 2               Faded                    Alan Walker  Electronic
# 3               Faded                    Alan Walker  Electronic
# 4   Bohemian Rhapsody                          Queen        Rock
# ..                ...                            ...         ...
# 95     Counting Stars                    OneRepublic    Pop Rock
# 96           Senorita  Shawn Mendes & Camila Cabello   Latin Pop
# 97     Counting Stars                    OneRepublic    Pop Rock
# 98    Blinding Lights                     The Weeknd   Synth-pop
# 99         Let Her Go                      Passenger       Indie
#
#     Release_Year  Duration_Minutes Listened_Date     Platform
# 0           2024              4.02    2024-02-10  Apple Music
# ...

# %%
df
# Out:
#            Song_Title                         Artist       Genre  \
# 0               Faded                    Alan Walker  Electronic
# 1     Blinding Lights                     The Weeknd   Synth-pop
# 2               Faded                    Alan Walker  Electronic
# 3               Faded                    Alan Walker  Electronic
# 4   Bohemian Rhapsody                          Queen        Rock
# ..                ...                            ...         ...
# 95     Counting Stars                    OneRepublic    Pop Rock
# 96           Senorita  Shawn Mendes & Camila Cabello   Latin Pop
# 97     Counting Stars                    OneRepublic    Pop Rock
# 98    Blinding Lights                     The Weeknd   Synth-pop
# 99         Let Her Go                      Passenger       Indie
#
#     Release_Year  Duration_Minutes Listened_Date     Platform
# 0           2024              4.02    2024-02-10  Apple Music
# ...

# %%
df.rename(columns={"Artist":"Singer"})
# Out:
#            Song_Title                         Singer       Genre  \
# 0               Faded                    Alan Walker  Electronic
# 1     Blinding Lights                     The Weeknd   Synth-pop
# 2               Faded                    Alan Walker  Electronic
# 3               Faded                    Alan Walker  Electronic
# 4   Bohemian Rhapsody                          Queen        Rock
# ..                ...                            ...         ...
# 95     Counting Stars                    OneRepublic    Pop Rock
# 96           Senorita  Shawn Mendes & Camila Cabello   Latin Pop
# 97     Counting Stars                    OneRepublic    Pop Rock
# 98    Blinding Lights                     The Weeknd   Synth-pop
# 99         Let Her Go                      Passenger       Indie
#
#     Release_Year  Duration_Minutes Listened_Date     Platform
# 0           2024              4.02    2024-02-10  Apple Music
# ...

# %%
df["Duration_Minutes"].unique()
# Out:
# array([4.02, 4.45, 4.86, 4.92, 3.9 , 4.65, 3.39, 2.67, 4.05, 3.98, 4.01,
#        4.24, 3.01, 3.25, 2.88, 4.79, 3.07, 2.83, 3.47, 4.26, 3.34, 2.71,
#        3.49, 4.07, 3.1 , 3.67, 4.64, 3.26, 4.82, 4.66, 4.35, 4.89, 3.83,
#        2.89, 4.16, 3.16, 4.33, 3.15, 2.7 , 3.69, 2.55, 3.19, 3.38, 4.59,
#        3.76, 4.37, 2.75, 2.54, 4.03, 4.7 , 4.93, 4.39, 2.97, 3.06, 3.61,
#        3.21, 4.34, 4.32, 4.42, 4.38, 3.24, 2.65, 4.25, 4.69, 2.79, 3.85,
#        2.87, 4.28, 3.08, 3.54, 4.99, 2.74, 4.75, 4.72, 4.43, 4.81, 3.43,
#        4.2 , 2.73, 2.92, 2.69, 4.9 , 3.14, 4.76, 4.23, 3.4 , 3.57, 4.04,
#        4.61])

# %%
df["Duration_Minutes"].value_counts()
# Out:
# Duration_Minutes
# 2.70    3
# 4.05    2
# 3.39    2
# 2.75    2
# 4.37    2
#        ..
# 4.23    1
# 3.40    1
# 3.57    1
# 4.04    1
# 4.61    1
# Name: count, Length: 89, dtype: int64

# %%
#Duplicates
df_dup = df[df.duplicated(keep=False)]
df_dup
# Out:
# Empty DataFrame
# Columns: [Song_Title, Artist, Genre, Release_Year, Duration_Minutes, Listened_Date, Platform]
# Index: []

# %%
#Matplotlib
data={
    "Salary" :[10000,12500,50000,30000,45000,54000,67000,70000,55000,30000,25000,45000,90000,80000,65000]
}
df2=pd.DataFrame(data)
df2
# Out:
#     Salary
# 0    10000
# 1    12500
# 2    50000
# 3    30000
# 4    45000
# 5    54000
# 6    67000
# 7    70000
# 8    55000
# 9    30000
# 10   25000
# 11   45000
# 12   90000
# 13   80000
# 14   65000

# %%
#line plot
plt.plot(df2['Salary'],color="black",marker="o",linestyle=":",linewidth="2")
plt.grid()

# %%
# Histogram
plt.hist(df2['Salary'],bins=7,color="red")
plt.show()

# %%
#Boxplot
plt.boxplot(df2['Salary'])
plt.show()

# %%
df2.shape
# Out:
# (15, 1)

# %%
df2.loc[60]=[0]

# %%
plt.boxplot(df2['Salary'])
plt.show()

# %%
df2.drop(index=60,inplace=True)
df2
# Out:
#     Salary
# 0    10000
# 1    12500
# 2    50000
# 3    30000
# 4    45000
# 5    54000
# 6    67000
# 7    70000
# 8    55000
# 9    30000
# 10   25000
# 11   45000
# 12   90000
# 13   80000
# 14   65000

# %%
#Univariate: Categorical

# %%
df2["dept"] = ['HR','IT','Finance','HR','IT','Finance','HR','Finance','HR','IT','Finance','Finance','HR','IT','Finance']

# %%
df2.shape
# Out:
# (15, 2)

# %%
#pichat
count=df2['dept'].value_counts()
count
# Out:
# dept
# Finance    6
# HR         5
# IT         4
# Name: count, dtype: int64

# %%
plt.pie(count,labels=count.index,autopct="%1.2f",explode=[0,0.1,0.2])
plt.axis("equal")
plt.show()

# %%
#Countplot
plt.bar(count.index,count,color=["red","green","yellow"])
plt.show()

# %%
df2['Age']=[23,34,32,21,43,35,37,28,30,49,24,35,43,28,27]

# %%
df2
# Out:
#     Salary     dept  Age
# 0    10000       HR   23
# 1    12500       IT   34
# 2    50000  Finance   32
# 3    30000       HR   21
# 4    45000       IT   43
# 5    54000  Finance   35
# 6    67000       HR   37
# 7    70000  Finance   28
# 8    55000       HR   30
# 9    30000       IT   49
# 10   25000  Finance   24
# 11   45000  Finance   35
# 12   90000       HR   43
# 13   80000       IT   28
# 14   65000  Finance   27

# %%
sort_age =df2.sort_values("Age")

# %%
#Scatter plot:

plt.scatter(df2["Age"],df2["Salary"],color ="red",marker="*")
plt.grid()
plt.show()

# %%
#line plot:
plt.plot(sort_age["Age"],df2["Salary"],color ="red",marker="*",linewidth="2")
plt.grid()
plt.show()

# %%
#bar chart:
plt.bar(sort_age["Age"],df2["Salary"],color = "pink",align="center")
plt.show()

# %%
#bivariate: Numerical - categorical

# %%
hr_sal=df2[df2["dept"]=="HR"]["Salary"]
hr_sal
# Out:
# 0     10000
# 3     30000
# 6     67000
# 8     55000
# 12    90000
# Name: Salary, dtype: int64

# %%
it_sal=df2[df2["dept"]=="IT"]["Salary"]
it_sal
# Out:
# 1     12500
# 4     45000
# 9     30000
# 13    80000
# Name: Salary, dtype: int64

# %%
fin_sal=df2[df2["dept"]=="Finance"]["Salary"]
fin_sal
# Out:
# 2     50000
# 5     54000
# 7     70000
# 10    25000
# 11    45000
# 14    65000
# Name: Salary, dtype: int64

# %%
#boxplot:
plt.boxplot([hr_sal,it_sal,fin_sal],labels=["HR","Finance","IT"])
plt.show()
# Out:
# /tmp/ipython-input-75-410062552.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([hr_sal,it_sal,fin_sal],labels=["HR","Finance","IT"])
